# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('../')
from default_constants import *
from plot_voltammogram_E import main_LSV_E_red

# %%
cst_all = default_constants()
cst_all["Ox"] = False
cst_all["E_0_1"] = -0.6
main_LSV_E_red(cst_all)
# Out:
# DM =  0.45 and lambda =  50
# array([-2.34015840e-17, -1.88716940e-17, -1.72603310e-17, ...,
#         3.62020430e-09,  3.61531031e-09,  3.61042784e-09])

# %%
from plot_voltammogram_E import main_CSV_E
main_CSV_E(cst_all)
# Out:
# DM =  0.45 and lambda =  50
# array([-1.14704706e-15, -8.32155687e-16, -6.78288950e-16, ...,
#         4.12447957e-09,  4.11872076e-09,  4.11297606e-09])

# %%
from plot_voltammogram_E import main_SWV_E
from plot_voltammogram_E import plot_SWV
print(cst_all["Ox"])
I = main_SWV_E(cst_all)
(E_for, I_for, E_rev, I_rev, Delta_I) = plot_SWV(cst_all, I)
# Out:
# False
# DM =  0.45 and lambda =  50
# Dt =  0.01884955592153876 and T = 2Pi/f =  0.25132741228718347
# YOU SHOULD INCREASE THE NUMBER OF TIME STEPS TO GET MEANINGFUL RESULTS !
