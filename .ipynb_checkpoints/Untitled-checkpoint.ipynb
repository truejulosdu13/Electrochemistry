# %%
from main import *
from default_constants import *

# %%
param = default_constants()

# %%
param["expe_type"] = 'CSV'

# %%
(param, E, C_init, M_new_constant, M_old, fun, fun_I) = initialise(dico)
plot_concentration_profiles(cst_all, E, C_init, M_new_constant, M_old, fun, fun_I)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-21728835fcd4> in <module>
#       1 (cst_all, E, C_init, M_new_constant, M_old, fun, fun_I) = initialise(dico)
# ----> 2 plot_concentration_profiles(cst_all, E, C_init, M_new_constant, M_old, fun, fun_I)
#
# ~/Desktop/These/Git_Electrochemistry/Electrochemistry/main.py in plot_concentration_profiles(cst_all, E, C_init, M_new_constant, M_old, fun, fun_I)
#     211         t = i*cst_all["Dt"]
#     212         M_new = fun(M_new_constant, t, E, cst_all)
# --> 213         C_new = compute_Cnew_E(M_new, M_old, C_old, cst_all["C_a"], cst_all["C_b"], cst_all["Nx"])
#     214
#     215         if cst_all["mechanism"] == 'E':
#
# ~/Desktop/These/Git_Electrochemistry/Electrochemistry/EDP_solver_tools.py in compute_Cnew_E(M_new, M_old, C_old, C_a, C_b, Nx)
#       9 def compute_Cnew_E(M_new, M_old, C_old, C_a, C_b, Nx):
# ...

# %%
(I, Potential, Time) = calculate_I(param, E, C_init, M_new_constant, M_old, fun, fun_I)

# %%
plt.plot(Potential, I)
