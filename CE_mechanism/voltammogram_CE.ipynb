# %%
import sys
import os
import matplotlib.pyplot as plt
import numpy as np
sys.path.append('../')
from default_constants import *
from plot_voltammogram_CE import main_LSV_CE

# %%
cst_all = default_constants()
cst_all["Ox"] = True
cst_all["E_0_1"] = 0.2
print(cst_all)
I = main_LSV_CE(cst_all)
# Out:
# {'R': 8.3145, 'T': 298.15, 'F': 96485, 'S': 1e-06, 'F_norm': 38.921435528312095, 'C_a': 0.002, 'C_b': 0.0, 'C_c': 0.0, 'C_d': 0.0, 'n_sp': 4, 'E_0_1': 0.2, 'E_0_2': -1.0, 'D': 1e-05, 'n': 1.0, 'alpha': 0.5, 'k0': 0.01, 'kc': 0.001, 'k_p': 1, 'k_m': 1, 'K': 1.0, 'Nt': 2000, 'Nx': 200, 'DM': 0.45, 'Lambda': 50, 'L_cuve': 2, 'Dx': 0.01, 'Ox': True, 'E_i': 0.0, 'E_ox': 0.5, 'E_red': -1.5, 'E_SW': 0.05, 'Delta_E': -0.01, 'v': 0.1, 'f': 25, 'tau': 1.0}
# DM =  0.45 and lambda =  50
# C_a_eq =  0.001 C_b_eq =  0.001 K = 1.0

# %%
from plot_voltammogram_CE import main_CSV_CE
I = main_CSV_CE(cst_all)
# Out:
# DM =  0.45 and lambda =  50
# C_a_eq =  0.001 C_b_eq =  0.001 K = 1.0

# %%
from plot_voltammogram_CE import main_SWV_CE
from plot_voltammogram_CE import plot_SWV
cst_all = default_constants()
cst_all["Ox"] = True
cst_all["Nt"] = 10000
print(cst_all)
I = main_SWV_CE(cst_all)
(E_for, I_for, E_rev, I_rev, Delta_I) = plot_SWV(cst_all, I)
# Out:
# {'R': 8.3145, 'T': 298.15, 'F': 96485, 'S': 1e-06, 'F_norm': 38.921435528312095, 'C_a': 0.002, 'C_b': 0.0, 'C_c': 0.0, 'C_d': 0.0, 'n_sp': 4, 'E_0_1': -0.5, 'E_0_2': -1.0, 'D': 1e-05, 'n': 1.0, 'alpha': 0.5, 'k0': 0.01, 'kc': 0.001, 'k_p': 1, 'k_m': 1, 'K': 1.0, 'Nt': 10000, 'Nx': 200, 'DM': 0.45, 'Lambda': 50, 'L_cuve': 2, 'Dx': 0.01, 'Ox': True, 'E_i': 0.0, 'E_ox': 0.5, 'E_red': -1.5, 'E_SW': 0.05, 'Delta_E': -0.01, 'v': 0.1, 'f': 25, 'tau': 1.0}
# DM =  0.45 and lambda =  50
# Dt =  0.0012566370614359172 and T = 2Pi/f =  0.25132741228718347
# C_a_eq =  0.001 C_b_eq =  0.001 K = 1.0

# %%
# Out:
# 2000
