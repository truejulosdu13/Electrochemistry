# %%
from main import *
from default_constants import *
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
viridis = cm.get_cmap('viridis', 12)
spectral = cm.get_cmap('Spectral', 9)
plasma = cm.get_cmap('plasma', 12)

# %%
param = default_constants()
param["Nx"] = 400
param["mechanism"] = 'AL'
param["E_0_1"]     = -1.0
param["E_0_2"]     = -0.8
param["k_p"]       = 0.01
param["k_p_2"]     = 0.001
param["k_m"]       = 0.00001
param["k_m_2"]     = 0.00001
param["kc"]        = 1
param["kc2"]       = 1
param["C_b"]       = 0.002
param["E_i"]       = 0.0
param["E_ox"]      = 0.1
param["E_red"]     = -1.5
param["v"]         = 0.1
param["Ox"]        = False
param["Reductible"]= True
(param, E, C_init, M_new_constant, M_old, fun, fun_I) = initialise(param)
(I, Potential, Time) = calculate_I(param, E, C_init, M_new_constant, M_old, fun, fun_I)
plt.plot(Potential, I)
# Out:
# C_a =  0.002 C_b =  0.002 C_c =  0.0 K = 999.9999999999999
# C_a_eq =  0.001 C_b_eq =  0.001 C_c_eq =  0.001 K = 999.9999999999999
# $\lambda$ =  0.25 DM =  2.56 v =  0.1

# %%
plot_concentration_profiles(param, E, C_init, M_new_constant, M_old, fun, fun_I)

# %%
plot_concentration_profiles(param, E, C_init, M_new_constant, M_old, fun, fun_I)

# %%
param
# Out:
# {'R': 8.3145,
#  'T': 298.15,
#  'F': 96485,
#  'S': 1e-06,
#  'F_norm': 38.921435528312095,
#  'C_a': 0.001934082207965583,
#  'C_b': 3.408220796558306e-05,
#  'C_c': 6.591779203441695e-05,
#  'C_d': 0.0,
#  'C_e': 0.0,
#  'num_species': 5,
#  'mechanism': 'AL',
#  'Reductible': True,
#  'E_0_1': -1.0,
#  'E_0_2': -0.5,
#  'D': 1e-05,
#  'n': 1,
#  'alpha': 0.5,
#  'k0': 0.01,
#  'k02': 0.01,
#  'kc': 0.1,
#  'kc2': 0.1,
#  'kc3': 0.001,
#  'k_p': 1,
#  'k_m': 0.001,
#  'k_p_2': 0.1,
#  'k_m_2': 0.0001,
#  'K': 1000.0,
#  'K_2': 0,
#  'Nt': 2000,
#  'Nx': 200,
#  'DM': 0.20000000000000004,
#  'Lambda': 1.0,
#  'L_cuve': 0.2,
#  'Dx': 0.001,
#  'expe_type': 'LSV',
#  'Ox': False,
#  'E_i': 0.0,
#  'E_ox': 0.5,
#  'E_red': -1.5,
#  'E_SW': 0.05,
#  'Delta_E': -0.01,
#  'v': 0.1,
#  'f': 25,
#  'tau': 1.0,
#  'exp_time': 40.0,
#  'K2': 1000.0,
#  'Dt': 0.02}

# %%
max(1,2)
# Out:
# 2

# %%
np.sqrt(2E-6)
# Out:
# 0.001414213562373095
